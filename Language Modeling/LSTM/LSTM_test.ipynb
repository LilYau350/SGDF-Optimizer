# %%
import os
#matplotlib notebook
import matplotlib.pyplot as plt
import torch
import numpy as np
import math

# %%
def get_data(names):
    folder_path = './curve'
    paths = [os.path.join(folder_path, name) for name in names]
    return {name: torch.load(fp) for name, fp in zip(names, paths)}

def plot(names, curve_type='train', labels = None, ylim=(30,110)):
    plt.figure()
    plt.ylim(ylim)# if curve_type == 'train' else 96)
    curve_data = get_data(names)
    for i, label in zip(curve_data.keys(),labels):
        acc = np.array(curve_data[i]['{}_loss'.format(curve_type.lower())])
        
        if label == 'SGDF':
            plt.plot(acc, '-' ,label = label)
        else:
            plt.plot(acc, '--',label=label)
    
    plt.grid()
    plt.legend(fontsize=14, loc='lower left')
    plt.title('{} set perplexity ~ training epoch'.format(curve_type))
    plt.xlabel('Training Epoch')
    plt.ylabel('Perplexity')

# %% [markdown]
# # LSTM 1-Layer

# %%
names = [ 'LSTM-PTB-niter-200-optimizer-sgdf-nlayers1-lr60.0-betas-0.9-0.999-eps1e-08-clip-0.1-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-sgd-nlayers1-lr30.0-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-adam-nlayers1-lr0.001-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-radam-nlayers1-lr0.001-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',            
          'LSTM-PTB-niter-200-optimizer-adamw-nlayers1-lr0.001-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-msvag-nlayers1-lr30.0-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',          
          'LSTM-PTB-niter-200-optimizer-adabound-nlayers1-lr0.001-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-yogi-nlayers1-lr0.01-betas-0.9-0.999-eps0.001-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-fromage-nlayers1-lr0.01-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',  
          'LSTM-PTB-niter-200-optimizer-adabelief-nlayers1-lr0.001-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',          
        ]

labels = ['SGDF',
          'SGD',
          'Adam',
          'RAdam',            
          'AdamW',
          'MSVAG', 
          'AdaBound',                 
          'Yogi',
          'Fromage',  
          'AdaBelief',
        ]

plot(names, 'Train', ylim=(50,100), labels = labels)
plot(names, 'Test', ylim=(82,100), labels = labels)

# %% [markdown]
# # LSTM 2-Layer

# %%
names = [ 'LSTM-PTB-niter-200-optimizer-sgdf-nlayers2-lr60.0-betas-0.9-0.999-eps1e-08-clip-0.15-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-sgd-nlayers2-lr30.0-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-adam-nlayers2-lr0.001-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-radam-nlayers2-lr0.001-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',            
          'LSTM-PTB-niter-200-optimizer-adamw-nlayers2-lr0.01-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-msvag-nlayers2-lr30.0-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',          
          'LSTM-PTB-niter-200-optimizer-adabound-nlayers2-lr0.001-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-yogi-nlayers2-lr0.01-betas-0.9-0.999-eps0.001-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-fromage-nlayers2-lr0.01-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',  
          'LSTM-PTB-niter-200-optimizer-adabelief-nlayers2-lr0.001-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
        ]

labels = ['SGDF',
          'SGD',
          'Adam',
          'RAdam',            
          'AdamW',
          'MSVAG', 
          'AdaBound',                 
          'Yogi',
          'Fromage',  
          'AdaBelief',
        ]

plot(names, 'Train', ylim=(40,90), labels = labels)
plot(names, 'Test', ylim=(66,82), labels = labels)

# %% [markdown]
# # LSTM 3-Layer

# %%
names = [ 'LSTM-PTB-niter-200-optimizer-sgdf-nlayers3-lr60.0-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-sgd-nlayers3-lr30.0-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-adam-nlayers3-lr0.001-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-radam-nlayers3-lr0.001-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',            
          'LSTM-PTB-niter-200-optimizer-adamw-nlayers3-lr0.001-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-msvag-nlayers3-lr30.0-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',          
          'LSTM-PTB-niter-200-optimizer-adabound-nlayers3-lr0.001-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-yogi-nlayers3-lr0.01-betas-0.9-0.999-eps0.001-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
          'LSTM-PTB-niter-200-optimizer-fromage-nlayers3-lr0.01-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',  
          'LSTM-PTB-niter-200-optimizer-adabelief-nlayers3-lr0.001-betas-0.9-0.999-eps1e-08-clip-0.25-wdecay1.2e-06-when-[100, 145]-run0',
        ]

labels = ['SGDF',
          'SGD',
          'Adam',
          'RAdam',            
          'AdamW',
          'MSVAG', 
          'AdaBound',                 
          'Yogi',
          'Fromage',
          'AdaBelief', 
        ]

plot(names, 'Train', ylim=(35,75), labels = labels)
plot(names, 'Test', ylim=(61,77), labels = labels)
